# %% [markdown]
# # Runtime

# %% [markdown]
# Langchain's create_agent runs on langgraph runtime under the hood, it has below info
# context - static info like user_id, DB connection or other dependencies for agent invocation
# store - long term memory - inmemorystore
# stream writer  - object used for streaming information
# server info
# execution info - identity and retry info for current execution ex: thread id, run id, attempt no
